# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import Image

# %%
data = pd.read_csv('Data/Part2_data.csv',header=0,index_col=0)

# %% [markdown]
# ## Categorical Data

# %%
categorical_data = data.select_dtypes(include=['object'])
for col in data.columns :
    uniques = data[col].unique()
    print("Column : "+col + ", number of uniques : " + str(len(uniques)))
    print(uniques)
    print("--------------------------------------------------------")
# Out:
# Column : Month, number of uniques : 12
# ['Dec' 'Jan' 'Oct' 'Jun' 'Feb' 'Mar' 'Aug' 'Apr' 'Jul' 'May' 'Sep' 'Nov']
# --------------------------------------------------------
# Column : WeekOfMonth, number of uniques : 5
# [5 3 2 1 4]
# --------------------------------------------------------
# Column : DayOfWeek, number of uniques : 7
# ['Wednesday' 'Friday' 'Saturday' 'Sunday' 'Monday' 'Tuesday' 'Thursday']
# --------------------------------------------------------
# Column : Make, number of uniques : 19
# ['Honda' 'Toyota' 'Mazda' 'Ford' 'Chevrolet' 'Pontiac' 'Dodge' 'Accura'
#  'Mercury' 'Jaguar' 'Nisson' 'VW' 'Saab' 'Saturn' 'Porche' 'BMW' 'Mecedes'
#  'Ferrari' 'Lexus']
# --------------------------------------------------------
# Column : AccidentArea, number of uniques : 2
# ['Urban' 'Rural']
# --------------------------------------------------------
# Column : DayOfWeekClaimed, number of uniques : 7
# ['Tuesday' 'Monday' 'Thursday' 'Friday' 'Wednesday' 'Saturday' 'Sunday']
# --------------------------------------------------------
# Column : MonthClaimed, number of uniques : 12
# ['Jan' 'Nov' 'Jul' 'Feb' 'Dec' 'Mar' 'Aug' 'May' 'Apr' 'Jun' 'Sep' 'Oct']
# --------------------------------------------------------
# Column : WeekOfMonthClaimed, number of uniques : 5
# [1 4 2 3 5]
# --------------------------------------------------------
# Column : Sex, number of uniques : 2
# ['Female' 'Male']
# --------------------------------------------------------
# Column : MaritalStatus, number of uniques : 4
# ['Single' 'Married' 'Widow' 'Divorced']
# --------------------------------------------------------
# Column : Age, number of uniques : 66
# [21. 34. 47. 65. 36. 30. 71. 52. 28.  0. 61. 38. 41. 40. 60. 39. 42. 27.
#  35. 44. 72. 29. 32. 37. 59. 49. 45. 26. 48. 31. 64. 55. 33. 74. 25. 23.
#  50. 16. 68. 51. 22. 53. 18. 46. 43. 57. 54. 19. 78. 77. 75. 56. 80. 67.
#  58. 69. 73. 24. 76. 62. 63. 70. 20. 66. 17. 79.]
# --------------------------------------------------------
# Column : Fault, number of uniques : 2
# ['Policy Holder' 'Third Party']
# --------------------------------------------------------
# Column : PolicyType, number of uniques : 9
# ['Sport - Liability' 'Sport - Collision' 'Sedan - Liability'
#  'Sedan - All Perils' 'Sedan - Collision' 'Utility - Collision'
#  'Utility - Liability' 'Utility - All Perils' 'Sport - All Perils']
# --------------------------------------------------------
# Column : VehicleCategory, number of uniques : 3
# ['Sport' 'Sedan' 'Utility']
# --------------------------------------------------------
# Column : VehiclePrice, number of uniques : 6
# ['more than 69000' '20000 to 29000' '30000 to 39000' 'less than 20000'
#  '40000 to 59000' '60000 to 69000']
# --------------------------------------------------------
# Column : FraudFound_P, number of uniques : 2
# [0 1]
# --------------------------------------------------------
# Column : PolicyNumber, number of uniques : 11553
# [    1     2     3 ... 15416 15419 15420]
# --------------------------------------------------------
# Column : RepNumber, number of uniques : 16
# [12 15  7  4 14 13 11  3 16  6  1  9  2  5  8 10]
# --------------------------------------------------------
# Column : Deductible, number of uniques : 4
# [300 400 500 700]
# --------------------------------------------------------
# Column : DriverRating, number of uniques : 4
# [1. 4. 3. 2.]
# --------------------------------------------------------
# Column : Days_Policy_Accident, number of uniques : 5
# ['more than 30' '15 to 30' 'none' '1 to 7' '8 to 15']
# --------------------------------------------------------
# Column : Days_Policy_Claim, number of uniques : 3
# ['more than 30' '15 to 30' '8 to 15']
# --------------------------------------------------------
# Column : PastNumberOfClaims, number of uniques : 4
# ['none' '1' '2 to 4' 'more than 4']
# --------------------------------------------------------
# Column : AgeOfVehicle, number of uniques : 8
# ['3 years' '6 years' '7 years' 'more than 7' 'new' '5 years' '4 years'
#  '2 years']
# --------------------------------------------------------
# Column : AgeOfPolicyHolder, number of uniques : 9
# ['26 to 30' '31 to 35' '41 to 50' '51 to 65' '36 to 40' 'over 65'
#  '16 to 17' '18 to 20' '21 to 25']
# --------------------------------------------------------
# Column : PoliceReportFiled, number of uniques : 2
# ['No' 'Yes']
# --------------------------------------------------------
# Column : WitnessPresent, number of uniques : 2
# ['No' 'Yes']
# --------------------------------------------------------
# Column : AgentType, number of uniques : 2
# ['External' 'Internal']
# --------------------------------------------------------
# Column : NumberOfSuppliments, number of uniques : 4
# ['none' 'more than 5' '1 to 2' '3 to 5']
# --------------------------------------------------------
# Column : AddressChange_Claim, number of uniques : 5
# ['1 year' 'no change' '4 to 8 years' '2 to 3 years' 'under 6 months']
# --------------------------------------------------------
# Column : NumberOfCars, number of uniques : 5
# ['3 to 4' '1 vehicle' '2 vehicles' '5 to 8' 'more than 8']
# --------------------------------------------------------
# Column : Year, number of uniques : 3
# [1994 1995 1996]
# --------------------------------------------------------
# Column : BasePolicy, number of uniques : 3
# ['Liability' 'Collision' 'All Perils']
# --------------------------------------------------------
# Column : ClaimSize, number of uniques : 3331
# [55526.06942128 59294.45557094 71756.94131971 ... 34883.15863324
#  18802.52485766 11105.10376426]
# --------------------------------------------------------

# %% [markdown]
# ***
#
# #### Ordinal Categories :
#
# - NumberOfCars
# - AddressChange_Claim
# - VehiclePrice
# - Days_Policy_Claim
# - AgeOfVehicle
# - AgeOfPolicyHolder
# - BasePolicy
# - MonthClaimed
#
# note : some categories are ordinal but have a *none* in their values so we have to treat them as nominal
#
# **Encoding Method : Ordinal (Label) Encoding**
#
# ***
#
# #### Nominal Categories with up to 3 unique values :
#
# - AccidentArea
# - Sex
# - Fault
# - VehicleCategory
# - PoliceReportFiled
# - WitnessPresent
# - AgentType
#
# **Encoding Method : One-Hot Encoding**
#
# ***
#
# #### Nominal Categories with more than 3 unique values :
#
# - Make
# - MaritalStatus
# - PolicyType
# - Days_Policy_Accident
# - PastNumberOfClaims
# - NumberOfSuppliments
#
# **Encoding Method : Binary Encoding Encoding**
#
# ***
#
# #### Less important categorical data :
#
# There are some Categorical data that seems to be less important on the fraud : <br>
#
# - Month  : The month of extracying data from database <br>
# - DayOfWeek : The day of the week of extracting data from database <br>
# - DayOfWeekClaimed : day of week in which the claim was made <br>
#
# Lets have a look on their pie charts:

# %%
Image("Figures/Part 1/Month.png")

# %%
Image("Figures/Part 1/DayOfWeek.png")

# %%
Image("Figures/Part 1/DayOfWeekClaimed.png")

# %% [markdown]
# The categorical data that we guessed to be less important, have a faily balanced pie charts (which show the percentage of fraud in their unique values) so we can remove them from the data.

# %%
data = data.drop(columns=["DayOfWeekClaimed","Month" ,"DayOfWeek"])
categorical_data = categorical_data.drop(columns=["DayOfWeekClaimed","Month" , "DayOfWeek"])

# %% [markdown]
# ### Ordinal Data Encoding / Engineering

# %%
data["NumberOfCars"] = data["NumberOfCars"].map({'1 vehicle':0,
                                                 '2 vehicles' :1 ,
                                                 '3 to 4' : 2 ,
                                                 '5 to 8' : 3 ,
                                                 'more than 8' : 4}).astype("int64")

data["AddressChange_Claim"] = data["AddressChange_Claim"].map({'no change':0,
                                                               'under 6 months':1,
                                                               '1 year' :2 ,
                                                               '2 to 3 years' : 3 ,
                                                               '4 to 8 years' : 4 }).astype("int64")

data["VehiclePrice"] = data["VehiclePrice"].map({'less than 20000':0,
                                                 '20000 to 29000':1,
                                                 '30000 to 39000' :2 ,
                                                 '40000 to 59000' : 3 ,
                                                 '60000 to 69000' : 4 ,
                                                 'more than 69000' : 5 }).astype("int64")

data["Days_Policy_Claim"] = data["Days_Policy_Claim"].map({'8 to 15':0,
                                                           '15 to 30':1,
                                                           'more than 30' :2 }).astype("int64")

data["AgeOfVehicle"] = data["AgeOfVehicle"].map({'new' : 0,
                                                 '2 years':1,
                                                 '3 years' :2 ,
                                                 '4 years' : 3 ,
                                                 '5 years' : 4 ,
                                                 '6 years' : 5 ,
                                                 '7 years' : 6 ,
                                                 'more than 7' : 7 }).astype("int64")

data["AgeOfPolicyHolder"] = data["AgeOfPolicyHolder"].map({'16 to 17' : 0,
                                                           '18 to 20':1,
                                                           '21 to 25' :2 ,
                                                           '26 to 30' : 3 ,
                                                           '31 to 35' : 4 ,
                                                           '36 to 40' : 5 ,
                                                           '41 to 50' : 6 ,
                                                           '51 to 65' : 7 ,
                                                           'over 65' : 8 }).astype("int64")
data["MonthClaimed"] = data["MonthClaimed"].map({'Jan' : 0,
                                                 'Feb':1,
                                                 'Mar' :2 ,
                                                 'Apr' : 3 ,
                                                 'May' : 4 ,
                                                 'Jun' : 5 ,
                                                 'Jul' : 6 ,
                                                 'Aug' : 7 ,
                                                 'Sep' : 8 ,
                                                 'Oct' : 9 ,
                                                 'Nov' : 10 ,
                                                 'Dec' : 11 }).astype("int64")

# %%
if not os.path.exists('Figures/Part 3'):
    os.makedirs('Figures/Part 3')
sns.set(style="white")
# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(12, 12))
# Generate a custom diverging colormap
corr = data.corr(numeric_only=True)
mask = np.triu(np.ones_like(corr, dtype = bool))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap,center=0,annot=True,mask=mask,fmt='.2f', cbar_kws={"shrink": .5},square=True, linewidths=.5)
fig.savefig("Figures/Part 3/heatmap.png")

# %% [markdown]
# #### Remove Redundancy

# %% [markdown]
# Highly corrolated features :
#
# - Year & PolicyNumber
# - Age & AgeOfPolicyHolder
#
# Between Age & AgeOfPolicyHolder I will keep Age because it also tells me about the AgeOfPlicyHolder
# Year and PolicyNumber are corrolated because PolicyNumber is a sequental number assigned to the polycyholders during the time.
# I will keep the Year becasue it tells me about the year the acciddent happend. Before removing the PolicyNumber lets see if we can find one policyholder who had several claims in the data or not.

# %%
len(data["PolicyNumber"].unique()) == data.shape[0]
# Out:
# True

# %% [markdown]
# if PolicyHolder doesn't tell us about the indivuals and their claim histories we can delete it.

# %%
data = data.drop(columns=["AgeOfPolicyHolder","PolicyNumber"])

# %% [markdown]
# ### Nominal Data Encoding/ Engineering

# %% [markdown]
# #### Remove Redundancy

# %% [markdown]
# Redundancy recognition and deletion in nominal data should be before the encoding. It is a bit more tricky than the ordinal data as we need to do it mannually and we can't use a heatmap for that.

# %%
categorical_data = data.select_dtypes(include=['object'])
categorical_data
# Out:
#             Make AccidentArea     Sex MaritalStatus          Fault  \
# 0          Honda        Urban  Female        Single  Policy Holder
# 1          Honda        Urban    Male        Single  Policy Holder
# 2          Honda        Urban    Male       Married  Policy Holder
# 3         Toyota        Rural    Male       Married    Third Party
# 4          Honda        Urban    Male       Married    Third Party
# ...          ...          ...     ...           ...            ...
# 11548      Mazda        Urban    Male       Married  Policy Holder
# 11549  Chevrolet        Urban    Male        Single    Third Party
# 11550     Toyota        Urban    Male       Married  Policy Holder
# 11551     Toyota        Urban  Female       Married    Third Party
# 11552     Toyota        Urban    Male        Single  Policy Holder
#
#                PolicyType VehicleCategory Days_Policy_Accident  \
# 0       Sport - Liability           Sport         more than 30
# 1       Sport - Collision           Sport         more than 30
# 2       Sport - Collision           Sport         more than 30
# 3       Sedan - Liability           Sport         more than 30
# 4       Sport - Collision           Sport         more than 30
# ...                   ...             ...                  ...
# 11548   Sedan - Liability           Sport         more than 30
# 11549   Sedan - Collision           Sedan         more than 30
# 11550   Sedan - Collision           Sedan         more than 30
# 11551  Sedan - All Perils           Sedan         more than 30
# 11552   Sedan - Collision           Sedan         more than 30
#
#       PastNumberOfClaims PoliceReportFiled WitnessPresent AgentType  \
# 0                   none                No             No  External
# 1                   none               Yes             No  External
# 2                      1                No             No  External
# 3                      1               Yes             No  External
# 4                      1                No             No  External
# ...                  ...               ...            ...       ...
# 11548                  1               Yes             No  External
# 11549               none                No             No  External
# 11550             2 to 4                No             No  External
# 11551               none                No             No  External
# 11552               none                No             No  External
#
#       NumberOfSuppliments  BasePolicy
# 0                    none   Liability
# 1                    none   Collision
# 2                    none   Collision
# 3             more than 5   Liability
# 4                  1 to 2   Collision
# ...                   ...         ...
# 11548              1 to 2   Liability
# 11549              1 to 2   Collision
# 11550                none   Collision
# 11551         more than 5  All Perils
# 11552              1 to 2   Collision
#
# [11553 rows x 14 columns]

# %%
# remove redundancy for nominal data

# %%
# delete numerical data that are not useful like weekofmonth, days plocy claim and accident
